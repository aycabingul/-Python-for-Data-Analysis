# %% [markdown]
# # **Appendix B: More on the IPython System**

# %% [markdown]
# ## **B.1 Using the Command History**

# %% [markdown]
# ### **Searching and Reusing the Command History**

# %%
# %run first/second/third/data_script.py

# %%
 a_command = foo(x, y, z)

# %% [markdown]
# (reverse-i-search)`com': a_command = foo(x, y, z)`

# %% [markdown]
# ### **Input and Output Variables**

# %%
2 ** 27

# %%
_

# %%
foo = 'bar'

# %%
foo

# %%
_i4

# %%
_4

# %%
exec(_i4)

# %% [markdown]
# ## **B.2 Interacting with the Operating System**

# %% [markdown]
# ### **Shell Commands and Aliases**

# %%
ip_info = !ifconfig wlan0 | grep "inet "

# %%
ip_info[0].strip()

# %%
foo = 'test*'

# %%
# !ls $foo

# %%
# %alias ll ls -l

# %%
ll /usr

# %%
# %alias test_alias (cd examples; ls; cd ..)

# %%
test_alias

# %% [markdown]
# ### **Directory Bookmark System**

# %%
# %bookmark py4da /home/wesm/code/pydata-book

# %%
cd py4da

# %%
# %bookmark -l

# %% [markdown]
# ## **B.3 Software Development Tools**

# %% [markdown]
# ### **Interactive Debugger**

# %%
# %run ../examples/ipython_bug.py

# %%
# %debug

# %% [markdown]
# %run -d ../examples/ipython_bug.py

# %% [markdown]
# #### **Other ways to make use of the debugger**

# %%
from IPython.core.debugger import Pdb

# %%
def set_trace():
    Pdb(color_scheme='Linux').set_trace(sys._getframe().f_back)

# %%
def debug(f, *args, **kwargs):
    pdb = Pdb(color_scheme='Linux')
    return pdb.runcall(f, *args, **kwargs)

# %%
# %run ../examples/ipython_bug.py

# %%
def f(x, y, z=1):
    tmp = x + y
    return tmp / z

# %%
# %debug(f, 1, 2, z=3)

# %%
# %run -d examples/ipython_bug.py

# %%
# %run -d -b2 examples/ipython_bug.py

# %% [markdown]
# ### **Timing Code: %time and %timeit**

# %%
import time
start = time.time()
for i in range(iterations):
    # some code to run here
elapsed_per = (time.time() - start) / iterations

# %%
# a very large list of strings
strings = ['foo', 'foobar', 'baz', 'qux',
 'python', 'Guido Van Rossum'] * 100000

method1 = [x for x in strings if x.startswith('foo')]
method2 = [x for x in strings if x[:3] == 'foo']

# %%
# %time method1 = [x for x in strings if x.startswith('foo')]

# %%
# %time method2 = [x for x in strings if x[:3] == 'foo']

# %%
# %timeit [x for x in strings if x.startswith('foo')]

# %%
# %timeit [x for x in strings if x[:3] == 'foo']

# %%
x = 'foobar'

# %%
y = 'foo'

# %%
# %timeit x.startswith(y)

# %%
# %timeit x[:3] == y

# %% [markdown]
# ### **Basic Profiling: %prun and %run -p**

# %%
import numpy as np
from numpy.linalg import eigvals

# %%
def run_experiment(niter=100):
    K = 100
    results = []
    for _ in xrange(niter):
        mat = np.random.randn(K, K)
        max_eigenvalue = np.abs(eigvals(mat)).max()
        results.append(max_eigenvalue)
    return results
some_results = run_experiment()
print ('Largest one we saw: %s' % np.max(some_results))

# %%
# %python -m cProfile cprof_example.py

# %%
$ python -m cProfile -s cumulative cprof_example.py

# %%
# %prun -l 7 -s cumulative run_experiment()

# %% [markdown]
# ### **Profiling a Function Line by Line**

# %%
# Yüklenecek IPython uzantılarının noktalı modül adlarının listesi.
c.TerminalIPythonApp.extensions = ['line_profiler']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-fb48110352e1> in <module>
#       1 # Yüklenecek IPython uzantılarının noktalı modül adlarının listesi.
# ----> 2 c.TerminalIPythonApp.extensions = ['line_profiler']
#
# NameError: name 'c' is not defined

# %%
# %load_ext line_profiler

# %%
from numpy.random import randn

def add_and_sum(x, y):
    added = x + y
    summed = added.sum(axis=1)
    return summed

def call_function():
    x = randn(1000, 1000)
    y = randn(1000, 1000)
    return add_and_sum(x, y)

# %%
# %run prof_mod
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /mnt/HDD/Belgeler/Çalışmalar/Tasarım-Bitirme/Python-for-Data-Analysis/da-venv/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# /mnt/HDD/Belgeler/Çalışmalar/Tasarım-Bitirme/Python-for-Data-Analysis/da-venv/lib/python3.8/site-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'prof_mod.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-5-0db8d5030e69> in <module>
# ----> 1 get_ipython().run_line_magic('run', 'prof_mod')
#
# /mnt/HDD/Belgeler/Çalışmalar/Tasarım-Bitirme/Python-for-Data-Analysis/da-venv/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2325                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2326             with self.builtin_trap:
# -> 2327                 result = fn(*args, **kwargs)
#    2328             return result
#    2329
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /mnt/HDD/Belgeler/Çalışmalar/Tasarım-Bitirme/Python-for-Data-Analysis/da-venv/lib/python3.8/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /mnt/HDD/Belgeler/Çalışmalar/Tasarım-Bitirme/Python-for-Data-Analysis/da-venv/lib/python3.8/site-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     712             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     713                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 714             raise Exception(msg)
#     715         except TypeError:
#     716             if fpath in sys.meta_path:
#
# Exception: File `'prof_mod.py'` not found.

# %%
x = randn(3000, 3000)
y = randn(3000, 3000)

# %prun add_and_sum(x, y)

# %%
# %lprun -f func1 -f func2 statement_to_profile

# %%
# %lprun -f add_and_sum -f call_function call_function()

# %% [markdown]
# ## **B.4 Tips for Productive Code Development Using IPython**

# %% [markdown]
# ### **Reloading Module Dependencies**

# %%
import some_lib

x = 5
y = [1, 2, 3, 4]
result = some_lib.get_answer(x, y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-58b5092e995f> in <module>
# ----> 1 import some_lib
#       2
#       3 x = 5
#       4 y = [1, 2, 3, 4]
#       5 result = some_lib.get_answer(x, y)
#
# ModuleNotFoundError: No module named 'some_lib'

# %%
import some_lib
import importlib
importlib.reload(some_lib)

# %% [markdown]
# ### **Code Design Tips**

# %% [markdown]
# #### **Keep relevant objects and data alive**

# %%
from my_functions import g
def f(x, y):
    return g(x + y)

def main():
    x = 6
    y = 7.5
    result = x + y
    
if __name__ == '__main__':
    main()
